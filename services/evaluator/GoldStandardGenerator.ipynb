# %%
import google.generativeai as genai
import pandas as pd
import json
import os
import re
import time
from pathlib import Path

# --- 1. Configuración ---

# ¡IMPORTANTE! Configura tu clave API de forma segura.
# (No la escribas directamente aquí en un script de producción)
try:
    API_KEY = os.environ["GEMINI_API_KEY"] 
    genai.configure(api_key=API_KEY)
except KeyError:
    print("Error: Configura la variable de entorno 'GEMINI_API_KEY'")
    exit()

# -------------------------------
# 2. List available models
# -------------------------------
try:
    models = genai.list_models()
    print("Available Google Generative AI Models:\n")
    for model in models:
        print(f"- {model.name} | Supported input: {model.input_token_limit} tokens")
except Exception as e:
    print(f"Error listing models: {e}")
# Out:
# Available Google Generative AI Models:
#
# - models/embedding-gecko-001 | Supported input: 1024 tokens
# - models/gemini-2.5-pro-preview-03-25 | Supported input: 1048576 tokens
# - models/gemini-2.5-flash-preview-05-20 | Supported input: 1048576 tokens
# - models/gemini-2.5-flash | Supported input: 1048576 tokens
# - models/gemini-2.5-flash-lite-preview-06-17 | Supported input: 1048576 tokens
# - models/gemini-2.5-pro-preview-05-06 | Supported input: 1048576 tokens
# - models/gemini-2.5-pro-preview-06-05 | Supported input: 1048576 tokens
# - models/gemini-2.5-pro | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-exp | Supported input: 1048576 tokens
# - models/gemini-2.0-flash | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-001 | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-exp-image-generation | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-lite-001 | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-lite | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-preview-image-generation | Supported input: 32768 tokens
# - models/gemini-2.0-flash-lite-preview-02-05 | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-lite-preview | Supported input: 1048576 tokens
# - models/gemini-2.0-pro-exp | Supported input: 1048576 tokens
# - models/gemini-2.0-pro-exp-02-05 | Supported input: 1048576 tokens
# - models/gemini-exp-1206 | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-thinking-exp-01-21 | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-thinking-exp | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-thinking-exp-1219 | Supported input: 1048576 tokens
# - models/gemini-2.5-flash-preview-tts | Supported input: 8192 tokens
# - models/gemini-2.5-pro-preview-tts | Supported input: 8192 tokens
# - models/learnlm-2.0-flash-experimental | Supported input: 1048576 tokens
# - models/gemma-3-1b-it | Supported input: 32768 tokens
# - models/gemma-3-4b-it | Supported input: 32768 tokens
# - models/gemma-3-12b-it | Supported input: 32768 tokens
# - models/gemma-3-27b-it | Supported input: 131072 tokens
# - models/gemma-3n-e4b-it | Supported input: 8192 tokens
# - models/gemma-3n-e2b-it | Supported input: 8192 tokens
# - models/gemini-flash-latest | Supported input: 1048576 tokens
# - models/gemini-flash-lite-latest | Supported input: 1048576 tokens
# - models/gemini-pro-latest | Supported input: 1048576 tokens
# - models/gemini-2.5-flash-lite | Supported input: 1048576 tokens
# - models/gemini-2.5-flash-image-preview | Supported input: 32768 tokens
# - models/gemini-2.5-flash-image | Supported input: 32768 tokens
# - models/gemini-2.5-flash-preview-09-2025 | Supported input: 1048576 tokens
# - models/gemini-2.5-flash-lite-preview-09-2025 | Supported input: 1048576 tokens
# - models/gemini-robotics-er-1.5-preview | Supported input: 1048576 tokens
# - models/gemini-2.5-computer-use-preview-10-2025 | Supported input: 131072 tokens
# - models/embedding-001 | Supported input: 2048 tokens
# - models/text-embedding-004 | Supported input: 2048 tokens
# - models/gemini-embedding-exp-03-07 | Supported input: 8192 tokens
# - models/gemini-embedding-exp | Supported input: 8192 tokens
# - models/gemini-embedding-001 | Supported input: 2048 tokens
# - models/aqa | Supported input: 7168 tokens
# - models/imagen-4.0-generate-preview-06-06 | Supported input: 480 tokens
# - models/imagen-4.0-ultra-generate-preview-06-06 | Supported input: 480 tokens
# - models/imagen-4.0-generate-001 | Supported input: 480 tokens
# - models/imagen-4.0-ultra-generate-001 | Supported input: 480 tokens
# - models/imagen-4.0-fast-generate-001 | Supported input: 480 tokens
# - models/veo-2.0-generate-001 | Supported input: 480 tokens
# - models/veo-3.0-generate-preview | Supported input: 480 tokens
# - models/veo-3.0-fast-generate-preview | Supported input: 480 tokens
# - models/veo-3.0-generate-001 | Supported input: 480 tokens
# - models/veo-3.0-fast-generate-001 | Supported input: 480 tokens
# - models/veo-3.1-generate-preview | Supported input: 480 tokens
# - models/veo-3.1-fast-generate-preview | Supported input: 480 tokens
# - models/gemini-2.0-flash-live-001 | Supported input: 131072 tokens
# - models/gemini-live-2.5-flash-preview | Supported input: 1048576 tokens
# - models/gemini-2.5-flash-live-preview | Supported input: 1048576 tokens
# - models/gemini-2.5-flash-native-audio-latest | Supported input: 131072 tokens
# - models/gemini-2.5-flash-native-audio-preview-09-2025 | Supported input: 131072 tokens

# %%
MODEL_TO_USE = 'models/gemini-flash-latest'

# Configuración del modelo
model = genai.GenerativeModel(MODEL_TO_USE)

# --- 2. Definición de Rutas (Paths) ---
# Usa las rutas que especificaste
BASE_PATH = Path(r"D:\github\plnTallerRAG\data")
CORPUS_PATH = BASE_PATH / "corpus"
CHUNKS_CSV_PATH = BASE_PATH / "chunks_debug.csv"
OUTPUT_JSON_PATH = BASE_PATH / "gold_standard_dataset.json"

# --- 3. El "Meta-Prompt" (La clave del éxito) ---
# Este prompt le pide al modelo que actúe como un experto en evaluación
# y que genere las preguntas, respuestas y *pasajes relevantes*.
# --- 3. El "Meta-Prompt" (Corregido) ---
# Este prompt le pide al modelo que actúe como un experto en evaluación
# y que genere las preguntas, respuestas y *pasajes relevantes*.
PROMPT_TEMPLATE = """
Eres un experto en crear 'Padrón de Oro' (Gold Standard) para evaluar sistemas de Búsqueda Aumentada por Generación (RAG).
Tu tarea es leer el texto de un capítulo de un libro y generar {num_preguntas} preguntas de alta calidad que pongan a prueba la comprensión y la capacidad de síntesis de un sistema de búsqueda.

Para cada pregunta, debes proporcionar:
1.  `query`: La pregunta en sí. Debe ser clara y requerir información específica del texto.
2.  `ideal_answer`: Una respuesta concisa, objetiva y en lenguaje natural, basada ÚNICAMENTE en el texto proporcionado.
3.  `relevant_passages`: Una lista de los fragmentos de texto (pasajes) VERBATIM y EXACTOS del capítulo que contienen la información necesaria para responder la pregunta. Estos pasajes deben ser lo más cortos posible pero contener la evidencia completa.

Restricciones Importantes:
-   Genera preguntas que no se respondan con un simple "sí" o "no".
-   Genera preguntas que requieran conectar información de, potencialmente, varias partes del texto.
-   La respuesta JSON debe ser una lista de diccionarios, sin ningún otro texto introductorio o de cierre.

Devuelve el resultado como una lista JSON válida.

--- INICIO DEL TEXTO DEL CAPÍTULO ---
{chapter_text}
--- FIN DEL TEXTO DEL CAPÍTULO ---

Aquí está tu formato de salida JSON (una lista de diccionarios):
[
  {{  
    "query": "...",
    "ideal_answer": "...",
    "relevant_passages": ["...", "..."]
  }}, <-- ¡CORREGIDO!
  ...
]
"""

# --- 4. Funciones Auxiliares ---

def cargar_chunks(csv_path):
    """Carga el archivo CSV de chunks en un DataFrame de Pandas."""
    try:
        df = pd.read_csv(csv_path, encoding='utf-8')
        print(f"Cargados {len(df)} chunks desde '{csv_path}'")
        return df
    except FileNotFoundError:
        print(f"Error: No se encontró el archivo de chunks en '{csv_path}'")
        exit()
    except Exception as e:
        print(f"Error al leer el CSV: {e}")
        exit()

def llamar_api_gemini(prompt_completo):
    """Envía el prompt a la API de Gemini y parsea la respuesta JSON."""
    try:
        response = model.generate_content(prompt_completo)
        
        # Limpiar la respuesta para extraer solo el JSON
        # (A veces la API envuelve la respuesta en ```json ... ```)
        json_match = re.search(r'\[.*\]', response.text, re.DOTALL)
        if not json_match:
            print("Error: La respuesta de la API no contenía un JSON válido.")
            print("Respuesta recibida:", response.text)
            return None

        json_string = json_match.group(0)
        return json.loads(json_string)
    
    except json.JSONDecodeError as e:
        print(f"Error al decodificar el JSON de la API: {e}")
        print("Respuesta recibida:", response.text)
        return None
    except Exception as e:
        print(f"Error en la llamada a la API: {e}")
        return None

def encontrar_chunks_relevantes(passages, chapter_chunks_df):
    """
    Mapea los pasajes de texto a los chunk_ids.
    Esta es la parte más delicada.
    """
    relevant_ids = set()
    for passage in passages:
        p_clean = passage.strip()
        if not p_clean:
            continue
        
        # Escapamos caracteres especiales para la búsqueda
        p_regex = re.escape(p_clean)

        # Buscar chunks que *contengan* el pasaje.
        # na=False es importante si hay valores NaN en 'text_content'
        try:
            matches = chapter_chunks_df[chapter_chunks_df['text_content'].str.contains(p_regex, na=False)]
            for chunk_id in matches['chunk_id']:
                relevant_ids.add(chunk_id)
        except Exception as e:
            print(f"Error durante la búsqueda de regex en el DataFrame: {e}")

    return sorted(list(relevant_ids))

# --- 5. Función Principal ---

def main():
    print("Iniciando la generación del 'Gold Standard'...")
    
    df_chunks = cargar_chunks(CHUNKS_CSV_PATH)
    
    gold_standard_dataset = []
    
    # Listar todos los archivos de texto en la carpeta corpus
    archivos_corpus = sorted(list(CORPUS_PATH.glob("*.txt")))
    total_archivos = len(archivos_corpus)
    
    print(f"Se encontraron {total_archivos} capítulos en '{CORPUS_PATH}'")

    for i, chapter_file_path in enumerate(archivos_corpus):
        chapter_filename = chapter_file_path.name
        print(f"\n--- Procesando Capítulo {i+1}/{total_archivos}: {chapter_filename} ---")
        
        try:
            with open(chapter_file_path, 'r', encoding='utf-8') as f:
                chapter_text = f.read()
        except Exception as e:
            print(f"Error al leer el archivo {chapter_filename}: {e}")
            continue
            
        # 1. Preparar el prompt para este capítulo
        prompt_completo = PROMPT_TEMPLATE.format(
            num_preguntas=3, # Pides 3 preguntas por capítulo
            chapter_text=chapter_text
        )
        
        # 2. Llamar a la API
        print("Enviando solicitud a la API de Gemini...")
        generated_data = llamar_api_gemini(prompt_completo)
        
        if not generated_data:
            print(f"No se pudo generar datos para {chapter_filename}. Saltando.")
            continue
            
        print(f"API respondió con {len(generated_data)} preguntas.")
        
        # 3. Filtrar los chunks relevantes para este capítulo
        chapter_chunks_df = df_chunks[df_chunks['source_document'] == chapter_filename].copy()
        if chapter_chunks_df.empty:
            print(f"Advertencia: No se encontraron chunks para {chapter_filename} en el CSV.")
            continue
            
        # 4. Mapear pasajes a chunks para cada pregunta generada
        for qa_item in generated_data:
            query = qa_item.get("query")
            ideal_answer = qa_item.get("ideal_answer")
            passages = qa_item.get("relevant_passages", [])
            
            if not all([query, ideal_answer, passages]):
                print("Advertencia: Item de QA incompleto. Saltando.")
                continue

            # 5. Encontrar los chunk_ids
            relevant_chunk_ids = encontrar_chunks_relevantes(passages, chapter_chunks_df)
            
            if not relevant_chunk_ids:
                print(f"Advertencia: No se pudo mapear ningún chunk para la query: '{query[:50]}...'")
                # Opcional: podrías decidir no incluirlo si no hay chunks
                # continue
            
            # 6. Ensamblar el item del "Gold Standard"
            gold_standard_item = {
                "query": query,
                "relevant_chunk_ids": relevant_chunk_ids,
                "ideal_answer": ideal_answer,
                "source_chapter": chapter_filename # Añadir esto es buena idea
            }
            gold_standard_dataset.append(gold_standard_item)
            print(f"  + Query agregada: '{query[:70]}...' (Chunks: {relevant_chunk_ids})")

        # Pausa para evitar exceder los límites de la API
        time.sleep(2) # Ajusta según sea necesario

    # --- 6. Guardar el Resultado Final ---
    print(f"\nProcesamiento completado. Total de {len(gold_standard_dataset)} preguntas generadas.")
    
    try:
        with open(OUTPUT_JSON_PATH, 'w', encoding='utf-8') as f:
            json.dump(gold_standard_dataset, f, indent=2, ensure_ascii=False)
        print(f"¡Éxito! 'Gold Standard' guardado en: '{OUTPUT_JSON_PATH}'")
    except Exception as e:
        print(f"Error al guardar el archivo JSON final: {e}")

if __name__ == "__main__":
    main()
# Out:
# Iniciando la generación del 'Gold Standard'...
# Cargados 1351 chunks desde 'D:\github\plnTallerRAG\data\chunks_debug.csv'
# Se encontraron 36 capítulos en 'D:\github\plnTallerRAG\data\corpus'
#
# --- Procesando Capítulo 1/36: 01-prólogo.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuáles son los tres pilares del Sistema Integral para la Paz establec...' (Chunks: ['01-prólogo.txt_0003', '01-prólogo.txt_0004'])
#   + Query agregada: '¿Cuál fue la pregunta macro que orientó la investigación de la Comisió...' (Chunks: ['01-prólogo.txt_0013', '01-prólogo.txt_0014', '01-prólogo.txt_0017', '01-prólogo.txt_0018'])
#   + Query agregada: '¿De cuántos tomos y qué tipo de documento complementario consta el inf...' (Chunks: ['01-prólogo.txt_0019'])
#
# --- Procesando Capítulo 2/36: 02-introducción.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
# Advertencia: No se pudo mapear ningún chunk para la query: '¿Qué tipos de información y variables específicas ...'
#   + Query agregada: '¿Qué tipos de información y variables específicas utilizó la Comisión ...' (Chunks: [])
#   + Query agregada: 'Identifique las 'grietas o fallas geológicas' en la construcción de la...' (Chunks: ['02-introducción.txt_0009', '02-introducción.txt_0010'])
#   + Query agregada: '¿Cuál fue el principal logro político alcanzado al finalizar el Segund...' (Chunks: ['02-introducción.txt_0038', '02-introducción.txt_0039', '02-introducción.txt_0040', '02-introducción.txt_0041'])
#
# --- Procesando Capítulo 3/36: 03-Antecedentes históricos (1920-1958).txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál fue la dinámica de la relación bilateral entre Colombia y Estado...' (Chunks: ['03-Antecedentes históricos (1920-1958).txt_0005', '03-Antecedentes históricos (1920-1958).txt_0006'])
#   + Query agregada: 'Describa las características de las 'economías de enclave' impulsadas ...' (Chunks: ['03-Antecedentes históricos (1920-1958).txt_0008', '03-Antecedentes históricos (1920-1958).txt_0009', '03-Antecedentes históricos (1920-1958).txt_0010'])
#   + Query agregada: 'Explique el papel del anticomunismo y la frustración agraria en la esc...' (Chunks: ['03-Antecedentes históricos (1920-1958).txt_0016', '03-Antecedentes históricos (1920-1958).txt_0017', '03-Antecedentes históricos (1920-1958).txt_0018'])
#
# --- Procesando Capítulo 4/36: 04-El miedo al comunismo.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿De qué manera la incapacidad del estado colombiano para solucionar el...' (Chunks: ['04-El miedo al comunismo.txt_0001', '04-El miedo al comunismo.txt_0002', '04-El miedo al comunismo.txt_0003', '04-El miedo al comunismo.txt_0007', '04-El miedo al comunismo.txt_0008'])
#   + Query agregada: '¿Qué condiciones de explotación laboral existían en el enclave de la U...' (Chunks: ['04-El miedo al comunismo.txt_0019', '04-El miedo al comunismo.txt_0023', '04-El miedo al comunismo.txt_0024'])
#   + Query agregada: '¿Cómo interpretó el gobierno conservador del presidente Miguel Abadía ...' (Chunks: ['04-El miedo al comunismo.txt_0015', '04-El miedo al comunismo.txt_0016', '04-El miedo al comunismo.txt_0017', '04-El miedo al comunismo.txt_0018'])
#
# --- Procesando Capítulo 5/36: 05-Reformas inconclusas.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cómo evolucionó la política agraria durante la República Liberal, pas...' (Chunks: ['05-Reformas inconclusas.txt_0009', '05-Reformas inconclusas.txt_0017', '05-Reformas inconclusas.txt_0018'])
#   + Query agregada: '¿Quiénes conformaron la oposición a las reformas de Alfonso López Puma...' (Chunks: ['05-Reformas inconclusas.txt_0014', '05-Reformas inconclusas.txt_0015', '05-Reformas inconclusas.txt_0016'])
#   + Query agregada: '¿Cuál era la noción colonial del territorio que predominó sobre region...' (Chunks: ['05-Reformas inconclusas.txt_0024', '05-Reformas inconclusas.txt_0025', '05-Reformas inconclusas.txt_0026', '05-Reformas inconclusas.txt_0027'])
#
# --- Procesando Capítulo 6/36: 06-La violencia como política.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cómo influyó la división del Partido Liberal en las elecciones de 194...' (Chunks: ['06-La violencia como política.txt_0004', '06-La violencia como política.txt_0008'])
#   + Query agregada: 'Además de la polarización bipartidista tradicional, ¿qué ideologías ex...' (Chunks: ['06-La violencia como política.txt_0002', '06-La violencia como política.txt_0011', '06-La violencia como política.txt_0012'])
#   + Query agregada: 'Detalle la transformación del levantamiento en Barrancabermeja después...' (Chunks: ['06-La violencia como política.txt_0030', '06-La violencia como política.txt_0031', '06-La violencia como política.txt_0032'])
#
# --- Procesando Capítulo 7/36: 07-Violencia que engendra violencia.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál fue la responsabilidad de los partidos Liberal y Conservador en ...' (Chunks: ['07-Violencia que engendra violencia.txt_0006', '07-Violencia que engendra violencia.txt_0007', '07-Violencia que engendra violencia.txt_0008'])
#   + Query agregada: 'Explique las diferencias ideológicas y de métodos entre los grupos de ...' (Chunks: ['07-Violencia que engendra violencia.txt_0016'])
#   + Query agregada: 'Describa el impacto que tuvo la participación de Colombia en la Guerra...' (Chunks: ['07-Violencia que engendra violencia.txt_0026', '07-Violencia que engendra violencia.txt_0027', '07-Violencia que engendra violencia.txt_0028'])
#
# --- Procesando Capítulo 8/36: 08-Una dictadura inducida.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál fue el lema inicial de la amnistía decretada por Rojas Pinilla a...' (Chunks: ['08-Una dictadura inducida.txt_0002', '08-Una dictadura inducida.txt_0015'])
#   + Query agregada: 'Describe la estrategia que el Partido Comunista Colombiano (PCC) adopt...' (Chunks: ['08-Una dictadura inducida.txt_0004', '08-Una dictadura inducida.txt_0006'])
# Advertencia: No se pudo mapear ningún chunk para la query: '¿Cuáles fueron los acuerdos centrales establecidos...'
#   + Query agregada: '¿Cuáles fueron los acuerdos centrales establecidos por los dirigentes ...' (Chunks: [])
#
# --- Procesando Capítulo 9/36: 09-¿Quién perdió_.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuáles son las estimaciones de víctimas mortales registradas para los...' (Chunks: ['09-¿Quién perdió_.txt_0000', '09-¿Quién perdió_.txt_0001'])
#   + Query agregada: 'Describa la secuencia de actos sanguinarios que se realizaban a los ca...' (Chunks: ['09-¿Quién perdió_.txt_0006', '09-¿Quién perdió_.txt_0007'])
#   + Query agregada: 'A pesar de que los campesinos fueron identificados como los grandes pe...' (Chunks: ['09-¿Quién perdió_.txt_0009', '09-¿Quién perdió_.txt_0010', '09-¿Quién perdió_.txt_0011', '09-¿Quién perdió_.txt_0012'])
#
# --- Procesando Capítulo 10/36: 10-De la paz política a la guerra insurgente (1958-1978).txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuáles fueron los ocho procesos concurrentes que explican el origen d...' (Chunks: ['10-De la paz política a la guerra insurgente (1958-1978).txt_0006'])
#   + Query agregada: '¿Cómo se dividen las valoraciones de los ensayistas de la CHCV respect...' (Chunks: ['10-De la paz política a la guerra insurgente (1958-1978).txt_0002', '10-De la paz política a la guerra insurgente (1958-1978).txt_0003', '10-De la paz política a la guerra insurgente (1958-1978).txt_0004'])
#   + Query agregada: '¿Qué consecuencias tuvo el sesgo del Frente Nacional contra actores po...' (Chunks: ['10-De la paz política a la guerra insurgente (1958-1978).txt_0001', '10-De la paz política a la guerra insurgente (1958-1978).txt_0007'])
#
# --- Procesando Capítulo 11/36: 11-Los paradigmas de la Guerra Fría.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuáles fueron los dos modelos mundiales que surgieron de la Segunda G...' (Chunks: ['11-Los paradigmas de la Guerra Fría.txt_0001', '11-Los paradigmas de la Guerra Fría.txt_0002', '11-Los paradigmas de la Guerra Fría.txt_0003'])
#   + Query agregada: '¿Qué potencias occidentales construyeron un cuerpo doctrinario de técn...' (Chunks: ['11-Los paradigmas de la Guerra Fría.txt_0004', '11-Los paradigmas de la Guerra Fría.txt_0005'])
#   + Query agregada: 'Tras el triunfo de la Revolución Cubana en 1959, ¿qué acciones estadou...' (Chunks: ['11-Los paradigmas de la Guerra Fría.txt_0008', '11-Los paradigmas de la Guerra Fría.txt_0009', '11-Los paradigmas de la Guerra Fría.txt_0013'])
#
# --- Procesando Capítulo 12/36: 12-Pacificación sin paz.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: 'Según el texto, ¿cuáles fueron los tres principales desafíos que enfre...' (Chunks: ['12-Pacificación sin paz.txt_0000', '12-Pacificación sin paz.txt_0001', '12-Pacificación sin paz.txt_0002'])
#   + Query agregada: '¿Cuál fue el contenido fundamental del llamado 'segundo pacto del fren...' (Chunks: ['12-Pacificación sin paz.txt_0012', '12-Pacificación sin paz.txt_0013', '12-Pacificación sin paz.txt_0014', '12-Pacificación sin paz.txt_0015'])
#   + Query agregada: '¿Cuáles fueron las recomendaciones hechas por la primera misión de coo...' (Chunks: ['12-Pacificación sin paz.txt_0044'])
#
# --- Procesando Capítulo 13/36: 13-Provocaciones y agravios.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál fue la secuencia de eventos, centrada en Jacobo Prías Álape (Cha...' (Chunks: ['13-Provocaciones y agravios.txt_0004', '13-Provocaciones y agravios.txt_0005', '13-Provocaciones y agravios.txt_0006', '13-Provocaciones y agravios.txt_0007', '13-Provocaciones y agravios.txt_0008', '13-Provocaciones y agravios.txt_0012'])
#   + Query agregada: '¿Cómo se diferenciaron las estrategias del Partido Comunista de la Uni...' (Chunks: ['13-Provocaciones y agravios.txt_0001', '13-Provocaciones y agravios.txt_0002', '13-Provocaciones y agravios.txt_0012', '13-Provocaciones y agravios.txt_0013'])
#   + Query agregada: 'Según el texto, ¿quién fue el político que popularizó el discurso de l...' (Chunks: ['13-Provocaciones y agravios.txt_0017', '13-Provocaciones y agravios.txt_0018', '13-Provocaciones y agravios.txt_0019', '13-Provocaciones y agravios.txt_0021', '13-Provocaciones y agravios.txt_0022'])
#
# --- Procesando Capítulo 14/36: 14-Las FARC.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál fue el objetivo declarado del Plan Lazo y bajo qué influencias e...' (Chunks: ['14-Las FARC.txt_0001', '14-Las FARC.txt_0002'])
#   + Query agregada: '¿Qué argumento sociopolítico sobre la violencia esgrimió el General Ru...' (Chunks: ['14-Las FARC.txt_0020', '14-Las FARC.txt_0021', '14-Las FARC.txt_0022'])
#   + Query agregada: '¿Cómo se vincula el ataque a Marquetalia con el mito fundacional de la...' (Chunks: ['14-Las FARC.txt_0012', '14-Las FARC.txt_0013', '14-Las FARC.txt_0036'])
#
# --- Procesando Capítulo 15/36: 15-Golpear y huir.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
# Advertencia: No se pudo mapear ningún chunk para la query: 'Describa la operación militar que llevó al ELN al ...'
#   + Query agregada: 'Describa la operación militar que llevó al ELN al borde de la extinció...' (Chunks: [])
# Advertencia: No se pudo mapear ningún chunk para la query: '¿Qué suceso generó una fisura insalvable entre el ...'
#   + Query agregada: '¿Qué suceso generó una fisura insalvable entre el gobierno de Alfonso ...' (Chunks: [])
#   + Query agregada: '¿Qué doctrinas de guerra guiaron al ELN y al EPL en sus inicios, y cuá...' (Chunks: ['15-Golpear y huir.txt_0005', '15-Golpear y huir.txt_0033', '15-Golpear y huir.txt_0034'])
#
# --- Procesando Capítulo 16/36: 16-Armar a los civiles.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué acción tomó el gobierno de Guillermo León Valencia en 1965 para r...' (Chunks: ['16-Armar a los civiles.txt_0000'])
#   + Query agregada: 'Según la doctrina contrainsurgente adoptada en Colombia, ¿quiénes fuer...' (Chunks: ['16-Armar a los civiles.txt_0004', '16-Armar a los civiles.txt_0005'])
#   + Query agregada: '¿Cuáles fueron las dos modalidades para la participación de los civile...' (Chunks: ['16-Armar a los civiles.txt_0006', '16-Armar a los civiles.txt_0007', '16-Armar a los civiles.txt_0008'])
#
# --- Procesando Capítulo 17/36: 17-¿Armas o reformas_.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué elementos esenciales de la reforma agraria promovida por Carlos L...' (Chunks: ['17-¿Armas o reformas_.txt_0009', '17-¿Armas o reformas_.txt_0010'])
#   + Query agregada: 'Explique la doble naturaleza institucional y social de la ANUC y cómo ...' (Chunks: ['17-¿Armas o reformas_.txt_0011', '17-¿Armas o reformas_.txt_0014', '17-¿Armas o reformas_.txt_0015', '17-¿Armas o reformas_.txt_0027', '17-¿Armas o reformas_.txt_0028'])
#   + Query agregada: '¿Qué principio ideológico llevó a los líderes indígenas del Cauca a fu...' (Chunks: ['17-¿Armas o reformas_.txt_0036', '17-¿Armas o reformas_.txt_0037', '17-¿Armas o reformas_.txt_0052', '17-¿Armas o reformas_.txt_0053', '17-¿Armas o reformas_.txt_0057'])
#
# --- Procesando Capítulo 18/36: 18-El agotamiento del pacto.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué anomalías rodearon el proceso electoral de 1970, y quiénes, décad...' (Chunks: ['18-El agotamiento del pacto.txt_0001', '18-El agotamiento del pacto.txt_0002', '18-El agotamiento del pacto.txt_0003', '18-El agotamiento del pacto.txt_0004', '18-El agotamiento del pacto.txt_0005'])
#   + Query agregada: 'De acuerdo con el texto, ¿a qué factores se atribuyó el éxito electora...' (Chunks: ['18-El agotamiento del pacto.txt_0008', '18-El agotamiento del pacto.txt_0009'])
#   + Query agregada: '¿Cuál fue la reacción del Estado y los partidos tradicionales frente a...' (Chunks: ['18-El agotamiento del pacto.txt_0005', '18-El agotamiento del pacto.txt_0006', '18-El agotamiento del pacto.txt_0010', '18-El agotamiento del pacto.txt_0011', '18-El agotamiento del pacto.txt_0014'])
#
# --- Procesando Capítulo 19/36: 19-¿Abrir la democracia a tiros_.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál fue la principal diferencia estratégica del M-19 respecto a las ...' (Chunks: ['19-¿Abrir la democracia a tiros_.txt_0003', '19-¿Abrir la democracia a tiros_.txt_0004', '19-¿Abrir la democracia a tiros_.txt_0005'])
#   + Query agregada: 'Según los testimonios a la Comisión de la Verdad, ¿qué consecuencias t...' (Chunks: ['19-¿Abrir la democracia a tiros_.txt_0013'])
#   + Query agregada: 'En el contexto de la relación entre el M-19 y el movimiento indígena e...' (Chunks: ['19-¿Abrir la democracia a tiros_.txt_0015', '19-¿Abrir la democracia a tiros_.txt_0016', '19-¿Abrir la democracia a tiros_.txt_0017'])
#
# --- Procesando Capítulo 20/36: 20-El paro cívico de 1977_ un pequeño 9 de abril.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuáles fueron los factores sociales, económicos y políticos que conve...' (Chunks: ['20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0002', '20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0004', '20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0013', '20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0014'])
#   + Query agregada: '¿Cómo difieren las perspectivas sobre la participación o la naturaleza...' (Chunks: ['20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0024', '20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0025', '20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0026'])
#   + Query agregada: 'Describa la reacción de los altos mandos militares después del Paro Cí...' (Chunks: ['20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0034', '20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0035', '20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0040'])
#
# --- Procesando Capítulo 21/36: 21-Una democracia represiva.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué evento de 1977 fue interpretado erróneamente tanto por las fuerza...' (Chunks: ['21-Una democracia represiva.txt_0001', '21-Una democracia represiva.txt_0002', '21-Una democracia represiva.txt_0004'])
#   + Query agregada: 'Además de restringir libertades fundamentales, ¿cuáles fueron los tres...' (Chunks: ['21-Una democracia represiva.txt_0007'])
#   + Query agregada: '¿Cuál fue la postura oficial del gobierno colombiano, resumida por Jul...' (Chunks: ['21-Una democracia represiva.txt_0048', '21-Una democracia represiva.txt_0049', '21-Una democracia represiva.txt_0050'])
#
# --- Procesando Capítulo 22/36: 22-El narcotráfico patea el tablero.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué factores específicos permitieron la consolidación y expansión del...' (Chunks: ['22-El narcotráfico patea el tablero.txt_0002'])
#   + Query agregada: 'Describa el método y el alcance de la entrada de dineros del narcotráf...' (Chunks: ['22-El narcotráfico patea el tablero.txt_0008', '22-El narcotráfico patea el tablero.txt_0009'])
#   + Query agregada: '¿Cómo evolucionó la relación entre las FARC-EP y el cultivo de coca en...' (Chunks: ['22-El narcotráfico patea el tablero.txt_0032', '22-El narcotráfico patea el tablero.txt_0036', '22-El narcotráfico patea el tablero.txt_0039', '22-El narcotráfico patea el tablero.txt_0040'])
#
# --- Procesando Capítulo 23/36: 23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cómo se diferenciaron los gobiernos de Belisario Betancur y César Gav...' (Chunks: ['23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt_0001', '23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt_0002'])
#   + Query agregada: '¿Qué estrategias específicas emplearon los capos narcotraficantes para...' (Chunks: ['23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt_0006', '23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt_0007'])
#   + Query agregada: 'Identifique las dos principales divisiones o pugnas ideológicas que se...' (Chunks: ['23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt_0004', '23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt_0005', '23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt_0009', '23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt_0010'])
#
# --- Procesando Capítulo 24/36: 24-Ni una gota más de sangre.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál fue el primer paso concreto dado por el gobierno de Belisario Be...' (Chunks: ['24-Ni una gota más de sangre.txt_0004', '24-Ni una gota más de sangre.txt_0005', '24-Ni una gota más de sangre.txt_0007', '24-Ni una gota más de sangre.txt_0008'])
#   + Query agregada: 'Según los testimonios recopilados por la Comisión de la Verdad, ¿cómo ...' (Chunks: ['24-Ni una gota más de sangre.txt_0050'])
#   + Query agregada: 'Hacia 1986, con la expansión de la presencia guerrillera en 172 munici...' (Chunks: ['24-Ni una gota más de sangre.txt_0024', '24-Ni una gota más de sangre.txt_0025'])
#
# --- Procesando Capítulo 25/36: 25-El MAS y la mentalidad paramilitar.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál fue el motivo inmediato para la creación del grupo Muerte a Secu...' (Chunks: ['25-El MAS y la mentalidad paramilitar.txt_0000', '25-El MAS y la mentalidad paramilitar.txt_0001', '25-El MAS y la mentalidad paramilitar.txt_0005', '25-El MAS y la mentalidad paramilitar.txt_0006'])
#   + Query agregada: 'Según el informe publicado por el procurador general Carlos Jiménez Gó...' (Chunks: ['25-El MAS y la mentalidad paramilitar.txt_0014', '25-El MAS y la mentalidad paramilitar.txt_0015', '25-El MAS y la mentalidad paramilitar.txt_0016'])
#   + Query agregada: 'Si bien existían civiles armados previamente, ¿por qué el MAS se consi...' (Chunks: ['25-El MAS y la mentalidad paramilitar.txt_0006', '25-El MAS y la mentalidad paramilitar.txt_0007', '25-El MAS y la mentalidad paramilitar.txt_0016', '25-El MAS y la mentalidad paramilitar.txt_0017'])
#
# --- Procesando Capítulo 26/36: 26-«Los enemigos agazapados de la paz».txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuáles fueron las acciones contradictorias tomadas por el gobierno y ...' (Chunks: ['26-«Los enemigos agazapados de la paz».txt_0002', '26-«Los enemigos agazapados de la paz».txt_0003'])
#   + Query agregada: 'Según los testimonios de los exguerrilleros citados en el texto, ¿cuál...' (Chunks: ['26-«Los enemigos agazapados de la paz».txt_0034', '26-«Los enemigos agazapados de la paz».txt_0035'])
#   + Query agregada: 'Identifique tres grupos o estamentos mencionados en el texto que se op...' (Chunks: ['26-«Los enemigos agazapados de la paz».txt_0000', '26-«Los enemigos agazapados de la paz».txt_0001'])
#
# --- Procesando Capítulo 27/36: 27-Una tregua imposible.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuáles fueron las diferencias estratégicas entre el M-19 y las FARC-E...' (Chunks: ['27-Una tregua imposible.txt_0007', '27-Una tregua imposible.txt_0008'])
#   + Query agregada: '¿De qué manera la doctrina del EPL de 'combinación de formas de lucha'...' (Chunks: ['27-Una tregua imposible.txt_0043', '27-Una tregua imposible.txt_0044', '27-Una tregua imposible.txt_0046'])
#   + Query agregada: 'Durante el proceso de paz de Betancur, ¿qué destino tuvieron los líder...' (Chunks: ['27-Una tregua imposible.txt_0014', '27-Una tregua imposible.txt_0062'])
#
# --- Procesando Capítulo 28/36: 28-La toma del Palacio de Justicia.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál fue el objetivo declarado del M-19 al tomarse el Palacio de Just...' (Chunks: ['28-La toma del Palacio de Justicia.txt_0000', '28-La toma del Palacio de Justicia.txt_0001', '28-La toma del Palacio de Justicia.txt_0002'])
#   + Query agregada: 'Según los testimonios y hallazgos, ¿cuáles fueron las tres decisiones ...' (Chunks: ['28-La toma del Palacio de Justicia.txt_0007', '28-La toma del Palacio de Justicia.txt_0008', '28-La toma del Palacio de Justicia.txt_0015'])
#   + Query agregada: 'En el marco de las investigaciones reabiertas, ¿en qué consistió la 't...' (Chunks: ['28-La toma del Palacio de Justicia.txt_0029', '28-La toma del Palacio de Justicia.txt_0031', '28-La toma del Palacio de Justicia.txt_0032'])
#
# --- Procesando Capítulo 29/36: 29-Democracia desde abajo.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué factores convergentes impulsaron el auge de la movilización socia...' (Chunks: ['29-Democracia desde abajo.txt_0001', '29-Democracia desde abajo.txt_0002', '29-Democracia desde abajo.txt_0003'])
#   + Query agregada: 'Describa los objetivos principales y el método de acción característic...' (Chunks: ['29-Democracia desde abajo.txt_0005', '29-Democracia desde abajo.txt_0006', '29-Democracia desde abajo.txt_0008'])
#   + Query agregada: 'Explique el doble rol que la descentralización jugó en el contexto de ...' (Chunks: ['29-Democracia desde abajo.txt_0012', '29-Democracia desde abajo.txt_0013', '29-Democracia desde abajo.txt_0014', '29-Democracia desde abajo.txt_0016', '29-Democracia desde abajo.txt_0017', '29-Democracia desde abajo.txt_0018'])
#
# --- Procesando Capítulo 30/36: 30-El genocidio de la Unión Patriótica.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: 'Describa la plataforma política central de la Unión Patriótica y cuant...' (Chunks: ['30-El genocidio de la Unión Patriótica.txt_0002'])
#   + Query agregada: '¿Cuál fue la evolución del vínculo entre la UP y las FARC-EP desde su ...' (Chunks: ['30-El genocidio de la Unión Patriótica.txt_0019', '30-El genocidio de la Unión Patriótica.txt_0021', '30-El genocidio de la Unión Patriótica.txt_0022'])
#   + Query agregada: 'Según los cálculos del cnmh y la Misión de Observación Electoral (MOE)...' (Chunks: ['30-El genocidio de la Unión Patriótica.txt_0030', '30-El genocidio de la Unión Patriótica.txt_0032', '30-El genocidio de la Unión Patriótica.txt_0033'])
#
# --- Procesando Capítulo 31/36: 31-La unidad guerrillera.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál fue la razón inicial de la expulsión de Javier Delgado de las FA...' (Chunks: ['31-La unidad guerrillera.txt_0005', '31-La unidad guerrillera.txt_0009'])
# Advertencia: No se pudo mapear ningún chunk para la query: 'Durante la gira por países socialistas, ¿qué resul...'
#   + Query agregada: 'Durante la gira por países socialistas, ¿qué resultados obtuvieron los...' (Chunks: [])
#   + Query agregada: 'Describa la 'reingeniería' del sector militar colombiano impulsada por...' (Chunks: ['31-La unidad guerrillera.txt_0019', '31-La unidad guerrillera.txt_0021', '31-La unidad guerrillera.txt_0022'])
#
# --- Procesando Capítulo 32/36: 32-La guerra sucia.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál fue la razón principal que el empresario Mario Zuluaga dio para ...' (Chunks: ['32-La guerra sucia.txt_0005'])
#   + Query agregada: 'Describe la configuración del modelo paramilitar en Puerto Boyacá, men...' (Chunks: ['32-La guerra sucia.txt_0011', '32-La guerra sucia.txt_0012'])
#   + Query agregada: '¿Qué hizo la jueza Marta Lucía González, que investigaba la red de sic...' (Chunks: ['32-La guerra sucia.txt_0027'])
#
# --- Procesando Capítulo 33/36: 33-Cría cuervos....txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cómo reaccionó el presidente Virgilio Barco a la declaración de guerr...' (Chunks: ['33-Cría cuervos....txt_0007', '33-Cría cuervos....txt_0008', '33-Cría cuervos....txt_0010', '33-Cría cuervos....txt_0011'])
#   + Query agregada: '¿Cuál era el propósito y la composición del Grupo Élite de la policía,...' (Chunks: ['33-Cría cuervos....txt_0011', '33-Cría cuervos....txt_0012', '33-Cría cuervos....txt_0013'])
#   + Query agregada: 'Según el texto, además de la lucha contra el estado, ¿qué dinámicas in...' (Chunks: ['33-Cría cuervos....txt_0001', '33-Cría cuervos....txt_0023', '33-Cría cuervos....txt_0024'])
#
# --- Procesando Capítulo 34/36: 34-Al filo del caos.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: 'Además de la crisis de legitimidad generada por el narcotráfico, ¿qué ...' (Chunks: ['34-Al filo del caos.txt_0000', '34-Al filo del caos.txt_0001', '34-Al filo del caos.txt_0002'])
# Advertencia: No se pudo mapear ningún chunk para la query: 'Según Antonio Navarro, ¿cuáles fueron las cinco ra...'
#   + Query agregada: 'Según Antonio Navarro, ¿cuáles fueron las cinco razones principales qu...' (Chunks: [])
#   + Query agregada: 'Explique cómo el asesinato de Galán activó el cambio constitucional de...' (Chunks: ['34-Al filo del caos.txt_0008', '34-Al filo del caos.txt_0009', '34-Al filo del caos.txt_0010', '34-Al filo del caos.txt_0013', '34-Al filo del caos.txt_0014'])
#
# --- Procesando Capítulo 35/36: 35-No es el pasado, es el futuro.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Quién propuso originalmente la idea de la Asamblea Nacional Constituy...' (Chunks: ['35-No es el pasado, es el futuro.txt_0000', '35-No es el pasado, es el futuro.txt_0003'])
# Advertencia: No se pudo mapear ningún chunk para la query: 'Además de su impacto económico y de seguridad, ¿cu...'
#   + Query agregada: 'Además de su impacto económico y de seguridad, ¿cuáles fueron las otra...' (Chunks: [])
# Advertencia: No se pudo mapear ningún chunk para la query: 'Según el testimonio de Otty Patiño a la Comisión d...'
#   + Query agregada: 'Según el testimonio de Otty Patiño a la Comisión de la Verdad, ¿cuál f...' (Chunks: [])
#
# --- Procesando Capítulo 36/36: 36-La paz.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué tipo de paz ha prevalecido en Colombia según el texto, y cuál es ...' (Chunks: ['36-La paz.txt_0000', '36-La paz.txt_0001'])
#   + Query agregada: 'A pesar de la fragilidad, ¿qué efecto han tenido los acuerdos de paz e...' (Chunks: ['36-La paz.txt_0000'])
#   + Query agregada: 'Según el texto, ¿cuál era la tríada de elementos que conformaban la pa...' (Chunks: ['36-La paz.txt_0002'])
#
# Procesamiento completado. Total de 108 preguntas generadas.
# ¡Éxito! 'Gold Standard' guardado en: 'D:\github\plnTallerRAG\data\gold_standard_dataset.json'
