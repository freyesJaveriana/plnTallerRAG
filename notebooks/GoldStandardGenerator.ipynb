# %% [markdown]
# # Taller RAG - Gold Standard Generator
# Docente: **Luis Gabriel Moreno Sandoval**
#
# ---
# *Grupo Número 1:*
#
# - LUCENA ORJUELA, JULIAN
# - MARTINEZ BERMUDEZ, JUAN
# - MONTENEGRO MAFLA, MARIA
# - REYES PALACIO, FELIPE
# ____
#
# Para la comparación de los modelos de Milvus y Solr, era necesario contar con preguntas tomadas del texto, y las respuestas ideales a las mismas, sin que dichas preguntas fueran excesivamente léxicas (es decir, utilizaran palabras diferentes a la respuesta ideal), de forma tal que la semántica; más que la simple léxica directa, fueran un patrón de evaluación más realista de los modelos.
#
# Este Notebook utiliza Google Gemini (API) para generar las preguntas, a partir de los textos de los capítulos del libro.

# %% [markdown]
# ## 1. Carga de librerías y validación de modelos
#
# Se cargan las librerías y se validan los modelos disponibles en la API de Google Gemini

# %%
import google.generativeai as genai
import pandas as pd
import json
import os
import re
import time
from pathlib import Path
from dotenv import load_dotenv

# --- 1. Configuración ---

# ¡IMPORTANTE! Configura tu clave API de forma segura.
# (No la escribas directamente aquí en un script de producción)
try:
    # Carga las variables del archivo .env
    load_dotenv()
    API_KEY = os.environ["GOOGLE_API_KEY"] 
    genai.configure(api_key=API_KEY)
except KeyError:
    print("Error: Configura la variable de entorno 'GOOGLE_API_KEY'")
    exit()

# -------------------------------
# 2. List available models
# -------------------------------
try:
    models = genai.list_models()
    print("Available Google Generative AI Models:\n")
    for model in models:
        print(f"- {model.name} | Supported input: {model.input_token_limit} tokens")
except Exception as e:
    print(f"Error listing models: {e}")
# Out:
# Available Google Generative AI Models:
#
# - models/embedding-gecko-001 | Supported input: 1024 tokens
# - models/gemini-2.5-pro-preview-03-25 | Supported input: 1048576 tokens
# - models/gemini-2.5-flash-preview-05-20 | Supported input: 1048576 tokens
# - models/gemini-2.5-flash | Supported input: 1048576 tokens
# - models/gemini-2.5-flash-lite-preview-06-17 | Supported input: 1048576 tokens
# - models/gemini-2.5-pro-preview-05-06 | Supported input: 1048576 tokens
# - models/gemini-2.5-pro-preview-06-05 | Supported input: 1048576 tokens
# - models/gemini-2.5-pro | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-exp | Supported input: 1048576 tokens
# - models/gemini-2.0-flash | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-001 | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-exp-image-generation | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-lite-001 | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-lite | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-preview-image-generation | Supported input: 32768 tokens
# - models/gemini-2.0-flash-lite-preview-02-05 | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-lite-preview | Supported input: 1048576 tokens
# - models/gemini-2.0-pro-exp | Supported input: 1048576 tokens
# - models/gemini-2.0-pro-exp-02-05 | Supported input: 1048576 tokens
# - models/gemini-exp-1206 | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-thinking-exp-01-21 | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-thinking-exp | Supported input: 1048576 tokens
# - models/gemini-2.0-flash-thinking-exp-1219 | Supported input: 1048576 tokens
# - models/gemini-2.5-flash-preview-tts | Supported input: 8192 tokens
# - models/gemini-2.5-pro-preview-tts | Supported input: 8192 tokens
# - models/learnlm-2.0-flash-experimental | Supported input: 1048576 tokens
# - models/gemma-3-1b-it | Supported input: 32768 tokens
# - models/gemma-3-4b-it | Supported input: 32768 tokens
# - models/gemma-3-12b-it | Supported input: 32768 tokens
# - models/gemma-3-27b-it | Supported input: 131072 tokens
# - models/gemma-3n-e4b-it | Supported input: 8192 tokens
# - models/gemma-3n-e2b-it | Supported input: 8192 tokens
# - models/gemini-flash-latest | Supported input: 1048576 tokens
# - models/gemini-flash-lite-latest | Supported input: 1048576 tokens
# - models/gemini-pro-latest | Supported input: 1048576 tokens
# - models/gemini-2.5-flash-lite | Supported input: 1048576 tokens
# - models/gemini-2.5-flash-image-preview | Supported input: 32768 tokens
# - models/gemini-2.5-flash-image | Supported input: 32768 tokens
# - models/gemini-2.5-flash-preview-09-2025 | Supported input: 1048576 tokens
# - models/gemini-2.5-flash-lite-preview-09-2025 | Supported input: 1048576 tokens
# - models/gemini-robotics-er-1.5-preview | Supported input: 1048576 tokens
# - models/gemini-2.5-computer-use-preview-10-2025 | Supported input: 131072 tokens
# - models/embedding-001 | Supported input: 2048 tokens
# - models/text-embedding-004 | Supported input: 2048 tokens
# - models/gemini-embedding-exp-03-07 | Supported input: 8192 tokens
# - models/gemini-embedding-exp | Supported input: 8192 tokens
# - models/gemini-embedding-001 | Supported input: 2048 tokens
# - models/aqa | Supported input: 7168 tokens
# - models/imagen-4.0-generate-preview-06-06 | Supported input: 480 tokens
# - models/imagen-4.0-ultra-generate-preview-06-06 | Supported input: 480 tokens
# - models/imagen-4.0-generate-001 | Supported input: 480 tokens
# - models/imagen-4.0-ultra-generate-001 | Supported input: 480 tokens
# - models/imagen-4.0-fast-generate-001 | Supported input: 480 tokens
# - models/veo-2.0-generate-001 | Supported input: 480 tokens
# - models/veo-3.0-generate-preview | Supported input: 480 tokens
# - models/veo-3.0-fast-generate-preview | Supported input: 480 tokens
# - models/veo-3.0-generate-001 | Supported input: 480 tokens
# - models/veo-3.0-fast-generate-001 | Supported input: 480 tokens
# - models/veo-3.1-generate-preview | Supported input: 480 tokens
# - models/veo-3.1-fast-generate-preview | Supported input: 480 tokens
# - models/gemini-2.0-flash-live-001 | Supported input: 131072 tokens
# - models/gemini-live-2.5-flash-preview | Supported input: 1048576 tokens
# - models/gemini-2.5-flash-live-preview | Supported input: 1048576 tokens
# - models/gemini-2.5-flash-native-audio-latest | Supported input: 131072 tokens
# - models/gemini-2.5-flash-native-audio-preview-09-2025 | Supported input: 131072 tokens

# %% [markdown]
# ## 2. Generación de las preguntas Gold Standard
#
# Se producen 3 preguntas, a partir de cada capítulo del libro, para un total de 108 preguntas máximo (si la pregunta no retorna un JSON válido, se descarta).   Cada pregunta tiene su respuesta ideal, además de los chunks donde se encuentra dicha respuesta.

# %%
MODEL_TO_USE = 'models/gemini-flash-latest'

# Configuración del modelo
model = genai.GenerativeModel(MODEL_TO_USE)

# --- 2. Definición de Rutas (Paths) ---
# Usa las rutas que especificaste
BASE_PATH = Path(r"D:\github\plnTallerRAG\data")
CORPUS_PATH = BASE_PATH / "corpus"
CHUNKS_CSV_PATH = BASE_PATH / "chunks_debug.csv"
OUTPUT_JSON_PATH = BASE_PATH / "gold_standard_dataset.json"

# --- 3. El "Meta-Prompt" (La clave del éxito) ---
# Este prompt le pide al modelo que actúe como un experto en evaluación
# y que genere las preguntas, respuestas y *pasajes relevantes*.
# --- 3. El "Meta-Prompt" (Corregido) ---
# Este prompt le pide al modelo que actúe como un experto en evaluación
# y que genere las preguntas, respuestas y *pasajes relevantes*.
PROMPT_TEMPLATE = """
Eres un experto en crear 'Padrón de Oro' (Gold Standard) para evaluar sistemas de Búsqueda Aumentada por Generación (RAG).
Tu tarea es leer el texto de un capítulo de un libro y generar {num_preguntas} preguntas de alta calidad que pongan a prueba la comprensión y la capacidad de síntesis de un sistema de búsqueda.

Para cada pregunta, debes proporcionar:
1.  `query`: La pregunta en sí.
2.  `ideal_answer`: Una respuesta concisa, objetiva y en lenguaje natural, basada ÚNICAMENTE en el texto proporcionado.
3.  `relevant_passages`: Una lista de los fragmentos de texto (pasajes) VERBATIM y EXACTOS del capítulo que contienen la información necesaria para responder la pregunta.

---
Restricciones Importantes:
-   **RESTRICCIÓN CLAVE (Calidad de Pregunta):** Las preguntas deben ser **conceptuales o semánticas**. Deben probar la comprensión del *significado* del texto, no solo la capacidad de encontrar una palabra clave (keyword matching).
-   **Ejemplo de qué EVITAR:** Si el texto dice "El MAS (Muerte a Secuestradores) fue un grupo paramilitar...", la pregunta NO debe ser "¿Qué fue el MAS?".
-   **Ejemplo de qué SÍ HACER:** Una pregunta conceptual para ese texto sería "¿Cuál fue el origen de los grupos de autodefensa financiados por narcotraficantes?".
-   Genera preguntas que no se respondan con un simple "sí" o "no".
-   Genera preguntas que requieran conectar información de, potencialmente, varias partes del texto (síntesis).
-   La respuesta JSON debe ser una lista de diccionarios, sin ningún otro texto introductorio o de cierre.
---

Devuelve el resultado como una lista JSON válida.

--- INICIO DEL TEXTO DEL CAPÍTULO ---
{chapter_text}
--- FIN DEL TEXTO DEL CAPÍTULO ---

Aquí está tu formato de salida JSON (una lista de diccionarios):
[
  {{
    "query": "...",
    "ideal_answer": "...",
    "relevant_passages": ["...", "..."]
  }},
  ...
]
"""

# --- 4. Funciones Auxiliares ---

def cargar_chunks(csv_path):
    """Carga el archivo CSV de chunks en un DataFrame de Pandas."""
    try:
        df = pd.read_csv(csv_path, encoding='utf-8')
        print(f"Cargados {len(df)} chunks desde '{csv_path}'")
        return df
    except FileNotFoundError:
        print(f"Error: No se encontró el archivo de chunks en '{csv_path}'")
        exit()
    except Exception as e:
        print(f"Error al leer el CSV: {e}")
        exit()

def llamar_api_gemini(prompt_completo):
    """Envía el prompt a la API de Gemini y parsea la respuesta JSON."""
    try:
        response = model.generate_content(prompt_completo)
        
        # Limpiar la respuesta para extraer solo el JSON
        # (A veces la API envuelve la respuesta en ```json ... ```)
        json_match = re.search(r'\[.*\]', response.text, re.DOTALL)
        if not json_match:
            print("Error: La respuesta de la API no contenía un JSON válido.")
            print("Respuesta recibida:", response.text)
            return None

        json_string = json_match.group(0)
        return json.loads(json_string)
    
    except json.JSONDecodeError as e:
        print(f"Error al decodificar el JSON de la API: {e}")
        print("Respuesta recibida:", response.text)
        return None
    except Exception as e:
        print(f"Error en la llamada a la API: {e}")
        return None

def encontrar_chunks_relevantes(passages, chapter_chunks_df):
    """
    Mapea los pasajes de texto a los chunk_ids.
    Esta es la parte más delicada.
    """
    relevant_ids = set()
    for passage in passages:
        p_clean = passage.strip()
        if not p_clean:
            continue
        
        # Escapamos caracteres especiales para la búsqueda
        p_regex = re.escape(p_clean)

        # Buscar chunks que *contengan* el pasaje.
        # na=False es importante si hay valores NaN en 'text_content'
        try:
            matches = chapter_chunks_df[chapter_chunks_df['text_content'].str.contains(p_regex, na=False)]
            for chunk_id in matches['chunk_id']:
                relevant_ids.add(chunk_id)
        except Exception as e:
            print(f"Error durante la búsqueda de regex en el DataFrame: {e}")

    return sorted(list(relevant_ids))

# --- 5. Función Principal ---

def main():
    print("Iniciando la generación del 'Gold Standard'...")
    
    df_chunks = cargar_chunks(CHUNKS_CSV_PATH)
    
    gold_standard_dataset = []
    
    # Listar todos los archivos de texto en la carpeta corpus
    archivos_corpus = sorted(list(CORPUS_PATH.glob("*.txt")))
    total_archivos = len(archivos_corpus)
    
    print(f"Se encontraron {total_archivos} capítulos en '{CORPUS_PATH}'")

    for i, chapter_file_path in enumerate(archivos_corpus):
        chapter_filename = chapter_file_path.name
        print(f"\n--- Procesando Capítulo {i+1}/{total_archivos}: {chapter_filename} ---")
        
        try:
            with open(chapter_file_path, 'r', encoding='utf-8') as f:
                chapter_text = f.read()
        except Exception as e:
            print(f"Error al leer el archivo {chapter_filename}: {e}")
            continue
            
        # 1. Preparar el prompt para este capítulo
        prompt_completo = PROMPT_TEMPLATE.format(
            num_preguntas=3, # Pides 3 preguntas por capítulo
            chapter_text=chapter_text
        )
        
        # 2. Llamar a la API
        print("Enviando solicitud a la API de Gemini...")
        generated_data = llamar_api_gemini(prompt_completo)
        
        if not generated_data:
            print(f"No se pudo generar datos para {chapter_filename}. Saltando.")
            continue
            
        print(f"API respondió con {len(generated_data)} preguntas.")
        
        # 3. Filtrar los chunks relevantes para este capítulo
        chapter_chunks_df = df_chunks[df_chunks['source_document'] == chapter_filename].copy()
        if chapter_chunks_df.empty:
            print(f"Advertencia: No se encontraron chunks para {chapter_filename} en el CSV.")
            continue
            
        # 4. Mapear pasajes a chunks para cada pregunta generada
        for qa_item in generated_data:
            query = qa_item.get("query")
            ideal_answer = qa_item.get("ideal_answer")
            passages = qa_item.get("relevant_passages", [])
            
            if not all([query, ideal_answer, passages]):
                print("Advertencia: Item de QA incompleto. Saltando.")
                continue

            # 5. Encontrar los chunk_ids
            relevant_chunk_ids = encontrar_chunks_relevantes(passages, chapter_chunks_df)
            
            if not relevant_chunk_ids:
                print(f"Advertencia: No se pudo mapear ningún chunk para la query: '{query[:50]}...'")
                # Opcional: podrías decidir no incluirlo si no hay chunks
                # continue
            
            # 6. Ensamblar el item del "Gold Standard"
            gold_standard_item = {
                "query": query,
                "relevant_chunk_ids": relevant_chunk_ids,
                "ideal_answer": ideal_answer,
                "source_chapter": chapter_filename # Añadir esto es buena idea
            }
            gold_standard_dataset.append(gold_standard_item)
            print(f"  + Query agregada: '{query[:70]}...' (Chunks: {relevant_chunk_ids})")

        # Pausa para evitar exceder los límites de la API
        time.sleep(2) # Ajusta según sea necesario

    # --- 6. Guardar el Resultado Final ---
    print(f"\nProcesamiento completado. Total de {len(gold_standard_dataset)} preguntas generadas.")
    
    try:
        with open(OUTPUT_JSON_PATH, 'w', encoding='utf-8') as f:
            json.dump(gold_standard_dataset, f, indent=2, ensure_ascii=False)
        print(f"¡Éxito! 'Gold Standard' guardado en: '{OUTPUT_JSON_PATH}'")
    except Exception as e:
        print(f"Error al guardar el archivo JSON final: {e}")

if __name__ == "__main__":
    main()
# Out:
# Iniciando la generación del 'Gold Standard'...
# Cargados 907 chunks desde 'D:\github\plnTallerRAG\data\chunks_debug.csv'
# Se encontraron 36 capítulos en 'D:\github\plnTallerRAG\data\corpus'
#
# --- Procesando Capítulo 1/36: 01-prólogo.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: 'Según la Comisión de la Verdad, ¿cómo redefinió conceptualmente el con...' (Chunks: ['01-prólogo.txt_0010', '01-prólogo.txt_0011', '01-prólogo.txt_0012'])
#   + Query agregada: '¿Cuál fue el método de investigación adoptado por la Comisión para la ...' (Chunks: ['01-prólogo.txt_0008', '01-prólogo.txt_0009'])
#   + Query agregada: 'Más allá de la función de registro histórico, ¿cuál fue el propósito s...' (Chunks: ['01-prólogo.txt_0021', '01-prólogo.txt_0022', '01-prólogo.txt_0023', '01-prólogo.txt_0024'])
#
# --- Procesando Capítulo 2/36: 02-introducción.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cómo delimitó la Comisión de la Verdad el periodo central de esclarec...' (Chunks: ['02-introducción.txt_0006', '02-introducción.txt_0007', '02-introducción.txt_0016', '02-introducción.txt_0017'])
#   + Query agregada: 'Además de las fallas geológicas en la construcción de la nación identi...' (Chunks: ['02-introducción.txt_0005', '02-introducción.txt_0006'])
#   + Query agregada: '¿Qué significado especial tiene el periodo entre 1996 y 2006 para el e...' (Chunks: ['02-introducción.txt_0018'])
#
# --- Procesando Capítulo 3/36: 03-Antecedentes históricos (1920-1958).txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cómo se manifestó la estrategia de inserción de las potencias capital...' (Chunks: ['03-Antecedentes históricos (1920-1958).txt_0004', '03-Antecedentes históricos (1920-1958).txt_0005'])
#   + Query agregada: '¿Cuál fue la lectura ideológica predominante que el Estado colombiano ...' (Chunks: ['03-Antecedentes históricos (1920-1958).txt_0007', '03-Antecedentes históricos (1920-1958).txt_0008'])
#   + Query agregada: 'Durante el periodo de la dictadura militar, ¿cuál fue el destino de la...' (Chunks: ['03-Antecedentes históricos (1920-1958).txt_0013', '03-Antecedentes históricos (1920-1958).txt_0014'])
#
# --- Procesando Capítulo 4/36: 04-El miedo al comunismo.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿De qué manera el sistema político y judicial colombiano, junto con la...' (Chunks: ['04-El miedo al comunismo.txt_0000', '04-El miedo al comunismo.txt_0001', '04-El miedo al comunismo.txt_0002', '04-El miedo al comunismo.txt_0004', '04-El miedo al comunismo.txt_0005'])
#   + Query agregada: '¿Cómo interpretó el gobierno conservador de Miguel Abadía Méndez el de...' (Chunks: ['04-El miedo al comunismo.txt_0009', '04-El miedo al comunismo.txt_0010', '04-El miedo al comunismo.txt_0011', '04-El miedo al comunismo.txt_0012'])
#   + Query agregada: 'Identifique las tres razones principales que causaron el fin de la heg...' (Chunks: ['04-El miedo al comunismo.txt_0020', '04-El miedo al comunismo.txt_0021'])
#
# --- Procesando Capítulo 5/36: 05-Reformas inconclusas.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál fue la principal limitación de la Ley 200 de 1936 respecto a la ...' (Chunks: ['05-Reformas inconclusas.txt_0003', '05-Reformas inconclusas.txt_0005', '05-Reformas inconclusas.txt_0006', '05-Reformas inconclusas.txt_0011', '05-Reformas inconclusas.txt_0012'])
#   + Query agregada: 'Antes del intento de modernización de la República Liberal, ¿qué funci...' (Chunks: ['05-Reformas inconclusas.txt_0000'])
#   + Query agregada: '¿Cómo la visión histórica de las regiones de la Amazonía y Orinoquía c...' (Chunks: ['05-Reformas inconclusas.txt_0015', '05-Reformas inconclusas.txt_0016', '05-Reformas inconclusas.txt_0017', '05-Reformas inconclusas.txt_0018'])
#
# --- Procesando Capítulo 6/36: 06-La violencia como política.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿De qué manera la práctica de la 'limpieza política', ejercida por los...' (Chunks: ['06-La violencia como política.txt_0003', '06-La violencia como política.txt_0004', '06-La violencia como política.txt_0005'])
#   + Query agregada: '¿Cuál fue la diferencia fundamental entre la lectura política que Jorg...' (Chunks: ['06-La violencia como política.txt_0007', '06-La violencia como política.txt_0008', '06-La violencia como política.txt_0009', '06-La violencia como política.txt_0010', '06-La violencia como política.txt_0025'])
#   + Query agregada: 'Según el testimonio de Gloria Gaitán, ¿por qué el asesinato de su padr...' (Chunks: ['06-La violencia como política.txt_0027', '06-La violencia como política.txt_0028'])
#
# --- Procesando Capítulo 7/36: 07-Violencia que engendra violencia.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿De qué manera los dos grandes partidos tradicionales contribuyeron al...' (Chunks: ['07-Violencia que engendra violencia.txt_0003', '07-Violencia que engendra violencia.txt_0004'])
#   + Query agregada: '¿Cuáles fueron las dos principales razones de la divergencia entre los...' (Chunks: ['07-Violencia que engendra violencia.txt_0010', '07-Violencia que engendra violencia.txt_0011'])
#   + Query agregada: '¿De qué manera la participación de Colombia en la Guerra de Corea (195...' (Chunks: ['07-Violencia que engendra violencia.txt_0017', '07-Violencia que engendra violencia.txt_0018'])
#
# --- Procesando Capítulo 8/36: 08-Una dictadura inducida.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cómo evolucionó la naturaleza del gobierno militar de Rojas Pinilla d...' (Chunks: ['08-Una dictadura inducida.txt_0000', '08-Una dictadura inducida.txt_0001', '08-Una dictadura inducida.txt_0002', '08-Una dictadura inducida.txt_0003', '08-Una dictadura inducida.txt_0006', '08-Una dictadura inducida.txt_0007'])
#   + Query agregada: 'Describa las características militares de la ofensiva contra Villarrri...' (Chunks: ['08-Una dictadura inducida.txt_0012', '08-Una dictadura inducida.txt_0013', '08-Una dictadura inducida.txt_0014', '08-Una dictadura inducida.txt_0015', '08-Una dictadura inducida.txt_0017', '08-Una dictadura inducida.txt_0018', '08-Una dictadura inducida.txt_0019'])
#   + Query agregada: '¿Cuál fue el mecanismo central de pacificación acordado en el Pacto de...' (Chunks: ['08-Una dictadura inducida.txt_0025', '08-Una dictadura inducida.txt_0026', '08-Una dictadura inducida.txt_0032'])
#
# --- Procesando Capítulo 9/36: 09-¿Quién perdió_.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál es la magnitud del despojo sufrido por los campesinos, evidencia...' (Chunks: ['09-¿Quién perdió_.txt_0001', '09-¿Quién perdió_.txt_0002', '09-¿Quién perdió_.txt_0003'])
#   + Query agregada: '¿Cómo se ejecutaba el ciclo de violencia posmortem conocido como 'cont...' (Chunks: ['09-¿Quién perdió_.txt_0004', '09-¿Quién perdió_.txt_0005'])
#   + Query agregada: 'Más allá del enfrentamiento bipartidista, ¿qué tipos de conflictos se ...' (Chunks: ['09-¿Quién perdió_.txt_0005', '09-¿Quién perdió_.txt_0006', '09-¿Quién perdió_.txt_0007', '09-¿Quién perdió_.txt_0008'])
#
# --- Procesando Capítulo 10/36: 10-De la paz política a la guerra insurgente (1958-1978).txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuáles fueron las dos perspectivas principales desde las que la Comis...' (Chunks: ['10-De la paz política a la guerra insurgente (1958-1978).txt_0003', '10-De la paz política a la guerra insurgente (1958-1978).txt_0004'])
# Advertencia: No se pudo mapear ningún chunk para la query: '¿Qué fallas sistémicas, relativas a la estructura ...'
#   + Query agregada: '¿Qué fallas sistémicas, relativas a la estructura de poder y la distri...' (Chunks: [])
#   + Query agregada: '¿De qué manera el pacto bipartidista del Frente Nacional radicalizó a ...' (Chunks: ['10-De la paz política a la guerra insurgente (1958-1978).txt_0000', '10-De la paz política a la guerra insurgente (1958-1978).txt_0001', '10-De la paz política a la guerra insurgente (1958-1978).txt_0004', '10-De la paz política a la guerra insurgente (1958-1978).txt_0005'])
#
# --- Procesando Capítulo 11/36: 11-Los paradigmas de la Guerra Fría.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué elementos distinguieron la 'guerra preventiva' que se consolidó c...' (Chunks: ['11-Los paradigmas de la Guerra Fría.txt_0001', '11-Los paradigmas de la Guerra Fría.txt_0002'])
#   + Query agregada: '¿Qué potencias occidentales y qué territorios funcionaron como laborat...' (Chunks: ['11-Los paradigmas de la Guerra Fría.txt_0002', '11-Los paradigmas de la Guerra Fría.txt_0003', '11-Los paradigmas de la Guerra Fría.txt_0011', '11-Los paradigmas de la Guerra Fría.txt_0012'])
#   + Query agregada: '¿Cuál era la estrategia revolucionaria del Che Guevara y cómo se manif...' (Chunks: ['11-Los paradigmas de la Guerra Fría.txt_0007', '11-Los paradigmas de la Guerra Fría.txt_0008', '11-Los paradigmas de la Guerra Fría.txt_0009', '11-Los paradigmas de la Guerra Fría.txt_0010'])
#
# --- Procesando Capítulo 12/36: 12-Pacificación sin paz.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿De qué manera el discurso de Lleras Camargo en el Teatro Patria defin...' (Chunks: ['12-Pacificación sin paz.txt_0003', '12-Pacificación sin paz.txt_0006', '12-Pacificación sin paz.txt_0008', '12-Pacificación sin paz.txt_0009'])
#   + Query agregada: 'A pesar de que el discurso oficial del Frente Nacional caracterizó a l...' (Chunks: ['12-Pacificación sin paz.txt_0002', '12-Pacificación sin paz.txt_0014', '12-Pacificación sin paz.txt_0015', '12-Pacificación sin paz.txt_0016', '12-Pacificación sin paz.txt_0018'])
#   + Query agregada: '¿Cuál fue el objetivo principal de la Ley 135 de 1961 de reforma agrar...' (Chunks: ['12-Pacificación sin paz.txt_0035', '12-Pacificación sin paz.txt_0036', '12-Pacificación sin paz.txt_0037', '12-Pacificación sin paz.txt_0038'])
#
# --- Procesando Capítulo 13/36: 13-Provocaciones y agravios.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué factores internos y externos llevaron al Partido Comunista Colomb...' (Chunks: ['13-Provocaciones y agravios.txt_0000', '13-Provocaciones y agravios.txt_0001', '13-Provocaciones y agravios.txt_0007', '13-Provocaciones y agravios.txt_0008'])
#   + Query agregada: '¿Cuál fue el conflicto específico que motivó a Marulanda a reactivar l...' (Chunks: ['13-Provocaciones y agravios.txt_0001', '13-Provocaciones y agravios.txt_0002', '13-Provocaciones y agravios.txt_0003', '13-Provocaciones y agravios.txt_0004', '13-Provocaciones y agravios.txt_0005'])
#   + Query agregada: 'Según el texto, ¿cuál fue el propósito inmediato del discurso de Álvar...' (Chunks: ['13-Provocaciones y agravios.txt_0011', '13-Provocaciones y agravios.txt_0012', '13-Provocaciones y agravios.txt_0013', '13-Provocaciones y agravios.txt_0014'])
#
# --- Procesando Capítulo 14/36: 14-Las FARC.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál era la filosofía central del Plan Lazo en la lucha contrainsurge...' (Chunks: ['14-Las FARC.txt_0001', '14-Las FARC.txt_0002'])
#   + Query agregada: '¿Qué factor ideológico fundamental provocó el enfrentamiento entre el ...' (Chunks: ['14-Las FARC.txt_0012', '14-Las FARC.txt_0013', '14-Las FARC.txt_0014', '14-Las FARC.txt_0015'])
#   + Query agregada: '¿Cómo difirió inicialmente el tratamiento militar de Riochiquito del a...' (Chunks: ['14-Las FARC.txt_0015', '14-Las FARC.txt_0016'])
#
# --- Procesando Capítulo 15/36: 15-Golpear y huir.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué diferencias fundamentales existieron entre el origen y el enfoque...' (Chunks: ['15-Golpear y huir.txt_0004'])
#   + Query agregada: '¿Cuál fue la influencia duradera de Camilo Torres Restrepo en la ideol...' (Chunks: ['15-Golpear y huir.txt_0009', '15-Golpear y huir.txt_0010'])
#   + Query agregada: 'Según el texto, ¿por qué la estrategia de contrainsurgencia militar de...' (Chunks: ['15-Golpear y huir.txt_0031', '15-Golpear y huir.txt_0032', '15-Golpear y huir.txt_0034', '15-Golpear y huir.txt_0035'])
#
# --- Procesando Capítulo 16/36: 16-Armar a los civiles.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál fue la justificación legal utilizada por el gobierno de Guillerm...' (Chunks: ['16-Armar a los civiles.txt_0000', '16-Armar a los civiles.txt_0001'])
#   + Query agregada: 'Según la doctrina contrainsurgente implementada en Colombia, ¿cómo se ...' (Chunks: ['16-Armar a los civiles.txt_0001', '16-Armar a los civiles.txt_0002', '16-Armar a los civiles.txt_0003'])
#   + Query agregada: 'Inicialmente, ¿quiénes conformaron las Juntas de Autodefensa autorizad...' (Chunks: ['16-Armar a los civiles.txt_0004', '16-Armar a los civiles.txt_0005'])
#
# --- Procesando Capítulo 17/36: 17-¿Armas o reformas_.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿De qué manera la presidencia de Misael Pastrana Borrero y el posterio...' (Chunks: ['17-¿Armas o reformas_.txt_0001', '17-¿Armas o reformas_.txt_0002', '17-¿Armas o reformas_.txt_0005', '17-¿Armas o reformas_.txt_0006', '17-¿Armas o reformas_.txt_0007', '17-¿Armas o reformas_.txt_0008'])
#   + Query agregada: '¿Cuáles fueron los motivos ideológicos específicos que llevaron a los ...' (Chunks: ['17-¿Armas o reformas_.txt_0023', '17-¿Armas o reformas_.txt_0024', '17-¿Armas o reformas_.txt_0025'])
#   + Query agregada: 'Explique cómo la 'opción preferencial por los pobres' influyó en la Ig...' (Chunks: ['17-¿Armas o reformas_.txt_0034', '17-¿Armas o reformas_.txt_0037', '17-¿Armas o reformas_.txt_0038', '17-¿Armas o reformas_.txt_0039'])
#
# --- Procesando Capítulo 18/36: 18-El agotamiento del pacto.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuáles fueron las razones principales del éxito inicial de la ANAPO e...' (Chunks: ['18-El agotamiento del pacto.txt_0004', '18-El agotamiento del pacto.txt_0005'])
#   + Query agregada: '¿Cómo impactó el supuesto fraude en las elecciones presidenciales de 1...' (Chunks: ['18-El agotamiento del pacto.txt_0002'])
#   + Query agregada: '¿De qué manera el pacto del Frente Nacional afectó la vitalidad de los...' (Chunks: ['18-El agotamiento del pacto.txt_0010', '18-El agotamiento del pacto.txt_0011', '18-El agotamiento del pacto.txt_0012', '18-El agotamiento del pacto.txt_0013', '18-El agotamiento del pacto.txt_0014'])
#
# --- Procesando Capítulo 19/36: 19-¿Abrir la democracia a tiros_.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuáles fueron las dos principales críticas estratégicas que motivaron...' (Chunks: ['19-¿Abrir la democracia a tiros_.txt_0000', '19-¿Abrir la democracia a tiros_.txt_0001', '19-¿Abrir la democracia a tiros_.txt_0002', '19-¿Abrir la democracia a tiros_.txt_0003', '19-¿Abrir la democracia a tiros_.txt_0004'])
#   + Query agregada: 'A pesar de que el M-19 fue percibido por sectores urbanos como un grup...' (Chunks: ['19-¿Abrir la democracia a tiros_.txt_0004', '19-¿Abrir la democracia a tiros_.txt_0005', '19-¿Abrir la democracia a tiros_.txt_0006'])
#   + Query agregada: '¿Qué motivó a algunos líderes indígenas del Cauca y Tolima a buscar ap...' (Chunks: ['19-¿Abrir la democracia a tiros_.txt_0009', '19-¿Abrir la democracia a tiros_.txt_0010', '19-¿Abrir la democracia a tiros_.txt_0012', '19-¿Abrir la democracia a tiros_.txt_0013'])
#
# --- Procesando Capítulo 20/36: 20-El paro cívico de 1977_ un pequeño 9 de abril.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuáles fueron los tres factores principales (demográficos, económicos...' (Chunks: ['20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0000', '20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0001', '20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0002'])
#   + Query agregada: 'A pesar de las esperanzas de cambio que generó el gobierno de López Mi...' (Chunks: ['20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0008', '20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0009'])
#   + Query agregada: '¿Cómo transformó el Paro Cívico Nacional de 1977 tanto la percepción d...' (Chunks: ['20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0022', '20-El paro cívico de 1977_ un pequeño 9 de abril.txt_0023'])
#
# --- Procesando Capítulo 21/36: 21-Una democracia represiva.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál fue la 'doble lectura' del paro cívico de septiembre de 1977 y c...' (Chunks: ['21-Una democracia represiva.txt_0000', '21-Una democracia represiva.txt_0001', '21-Una democracia represiva.txt_0002'])
#   + Query agregada: 'Según el texto, ¿cómo se manifiesta la transformación de la disidencia...' (Chunks: ['21-Una democracia represiva.txt_0003', '21-Una democracia represiva.txt_0004', '21-Una democracia represiva.txt_0005'])
#   + Query agregada: 'Analice la postura de los grandes medios de comunicación colombianos d...' (Chunks: ['21-Una democracia represiva.txt_0022', '21-Una democracia represiva.txt_0023', '21-Una democracia represiva.txt_0024'])
#
# --- Procesando Capítulo 22/36: 22-El narcotráfico patea el tablero.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué conjunto de factores permitió que Colombia se consolidara como el...' (Chunks: ['22-El narcotráfico patea el tablero.txt_0001', '22-El narcotráfico patea el tablero.txt_0002', '22-El narcotráfico patea el tablero.txt_0003'])
#   + Query agregada: 'Describa la evolución en la postura de las FARC-EP hacia la economía d...' (Chunks: ['22-El narcotráfico patea el tablero.txt_0021', '22-El narcotráfico patea el tablero.txt_0023', '22-El narcotráfico patea el tablero.txt_0024', '22-El narcotráfico patea el tablero.txt_0026'])
#   + Query agregada: '¿De qué manera la adquisición masiva de tierras por parte de los narco...' (Chunks: ['22-El narcotráfico patea el tablero.txt_0031', '22-El narcotráfico patea el tablero.txt_0032'])
#
# --- Procesando Capítulo 23/36: 23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué fuerzas convergieron en Colombia durante los años ochenta con el ...' (Chunks: ['23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt_0000', '23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt_0002', '23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt_0003'])
#   + Query agregada: '¿Cómo los capos narcotraficantes buscaron consolidar su influencia en ...' (Chunks: ['23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt_0003', '23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt_0004'])
#   + Query agregada: '¿Quiénes fueron los principales blancos de la violencia durante el per...' (Chunks: ['23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt_0004', '23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt_0005', '23-La búsqueda de la democracia y la guerra sucia (1978-1990).txt_0006'])
#
# --- Procesando Capítulo 24/36: 24-Ni una gota más de sangre.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué mensaje clave buscaba transmitir el presidente Betancur al tramit...' (Chunks: ['24-Ni una gota más de sangre.txt_0004', '24-Ni una gota más de sangre.txt_0005', '24-Ni una gota más de sangre.txt_0006'])
# Advertencia: No se pudo mapear ningún chunk para la query: 'A principios de los años ochenta, ¿cuáles fueron l...'
#   + Query agregada: 'A principios de los años ochenta, ¿cuáles fueron los cuatro factores e...' (Chunks: [])
#   + Query agregada: '¿Cuál fue la justificación principal de las guerrillas para recurrir a...' (Chunks: ['24-Ni una gota más de sangre.txt_0018', '24-Ni una gota más de sangre.txt_0019', '24-Ni una gota más de sangre.txt_0032', '24-Ni una gota más de sangre.txt_0033'])
#
# --- Procesando Capítulo 25/36: 25-El MAS y la mentalidad paramilitar.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué elementos convirtió al MAS en el “hito fundacional del paramilita...' (Chunks: ['25-El MAS y la mentalidad paramilitar.txt_0003', '25-El MAS y la mentalidad paramilitar.txt_0004'])
#   + Query agregada: 'Según el informe de la Procuraduría de 1983, ¿qué concepto más amplio ...' (Chunks: ['25-El MAS y la mentalidad paramilitar.txt_0009', '25-El MAS y la mentalidad paramilitar.txt_0010'])
#   + Query agregada: 'Describa la evolución en el uso del nombre del MAS, desde su propósito...' (Chunks: ['25-El MAS y la mentalidad paramilitar.txt_0008', '25-El MAS y la mentalidad paramilitar.txt_0009', '25-El MAS y la mentalidad paramilitar.txt_0010', '25-El MAS y la mentalidad paramilitar.txt_0011'])
#
# --- Procesando Capítulo 26/36: 26-«Los enemigos agazapados de la paz».txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué posturas tomaron las diferentes facciones internas (militares y g...' (Chunks: ['26-«Los enemigos agazapados de la paz».txt_0000', '26-«Los enemigos agazapados de la paz».txt_0001', '26-«Los enemigos agazapados de la paz».txt_0002'])
#   + Query agregada: '¿Cuáles fueron las dos consecuencias inmediatas y cruciales del asesin...' (Chunks: ['26-«Los enemigos agazapados de la paz».txt_0009', '26-«Los enemigos agazapados de la paz».txt_0010', '26-«Los enemigos agazapados de la paz».txt_0011'])
#   + Query agregada: 'Explique la narrativa de la ‘narcoguerrilla’ acuñada por el embajador ...' (Chunks: ['26-«Los enemigos agazapados de la paz».txt_0020', '26-«Los enemigos agazapados de la paz».txt_0021', '26-«Los enemigos agazapados de la paz».txt_0022'])
#
# --- Procesando Capítulo 27/36: 27-Una tregua imposible.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuáles fueron las diferencias estratégicas fundamentales entre el M-1...' (Chunks: ['27-Una tregua imposible.txt_0004'])
#   + Query agregada: '¿Cuál era la contradicción fundamental en la aproximación del Estado h...' (Chunks: ['27-Una tregua imposible.txt_0013', '27-Una tregua imposible.txt_0014'])
# Advertencia: No se pudo mapear ningún chunk para la query: '¿Qué doctrina utilizada por el EPL y su partido po...'
#   + Query agregada: '¿Qué doctrina utilizada por el EPL y su partido político, el PC-ML, se...' (Chunks: [])
#
# --- Procesando Capítulo 28/36: 28-La toma del Palacio de Justicia.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál fue el objetivo político del M-19 al tomarse el Palacio de Justi...' (Chunks: ['28-La toma del Palacio de Justicia.txt_0000'])
#   + Query agregada: 'La toma del Palacio de Justicia generó diversas tesis sobre la direcci...' (Chunks: ['28-La toma del Palacio de Justicia.txt_0003', '28-La toma del Palacio de Justicia.txt_0004', '28-La toma del Palacio de Justicia.txt_0009', '28-La toma del Palacio de Justicia.txt_0010'])
#   + Query agregada: 'Explique la diferencia conceptual que el gobierno de Belisario Betancu...' (Chunks: ['28-La toma del Palacio de Justicia.txt_0005', '28-La toma del Palacio de Justicia.txt_0006', '28-La toma del Palacio de Justicia.txt_0008'])
#
# --- Procesando Capítulo 29/36: 29-Democracia desde abajo.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué motivaciones complementarias impulsaron la implementación de la d...' (Chunks: ['29-Democracia desde abajo.txt_0011', '29-Democracia desde abajo.txt_0012'])
#   + Query agregada: 'Describe la evolución en el discurso y las demandas que experimentaron...' (Chunks: ['29-Democracia desde abajo.txt_0006', '29-Democracia desde abajo.txt_0007'])
#   + Query agregada: '¿Cuál fue la implicación práctica de que las fuerzas armadas percibier...' (Chunks: ['29-Democracia desde abajo.txt_0008', '29-Democracia desde abajo.txt_0009', '29-Democracia desde abajo.txt_0010', '29-Democracia desde abajo.txt_0011'])
#
# --- Procesando Capítulo 30/36: 30-El genocidio de la Unión Patriótica.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuáles fueron los dos principales factores (uno ideológico y otro est...' (Chunks: ['30-El genocidio de la Unión Patriótica.txt_0001'])
#   + Query agregada: '¿Cuál fue la ambigüedad que se hizo insostenible para la Unión Patriót...' (Chunks: ['30-El genocidio de la Unión Patriótica.txt_0014'])
#   + Query agregada: 'Según los testimonios y documentos recogidos por la Comisión de la Ver...' (Chunks: ['30-El genocidio de la Unión Patriótica.txt_0026'])
#
# --- Procesando Capítulo 31/36: 31-La unidad guerrillera.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué combinación de factores internos y externos llevó a la disolución...' (Chunks: ['31-La unidad guerrillera.txt_0005', '31-La unidad guerrillera.txt_0006'])
#   + Query agregada: 'Describa las principales transformaciones institucionales (reingenierí...' (Chunks: ['31-La unidad guerrillera.txt_0012', '31-La unidad guerrillera.txt_0013', '31-La unidad guerrillera.txt_0014'])
#   + Query agregada: '¿Cuál fue el evento de represalia específico que motivó a los narcotra...' (Chunks: ['31-La unidad guerrillera.txt_0014', '31-La unidad guerrillera.txt_0015'])
#
# --- Procesando Capítulo 32/36: 32-La guerra sucia.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: 'Aunque los grupos paramilitares se justificaban bajo una narrativa con...' (Chunks: ['32-La guerra sucia.txt_0008', '32-La guerra sucia.txt_0009'])
#   + Query agregada: '¿Cuál fue el dilema fundamental o la paradoja que enfrentó el Estado a...' (Chunks: ['32-La guerra sucia.txt_0021', '32-La guerra sucia.txt_0022'])
#   + Query agregada: 'Describe dos formas clave en que el establecimiento (militares y gobie...' (Chunks: ['32-La guerra sucia.txt_0006', '32-La guerra sucia.txt_0007'])
#
# --- Procesando Capítulo 33/36: 33-Cría cuervos....txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuál fue el cambio de enfoque que la declaración de guerra del presid...' (Chunks: ['33-Cría cuervos....txt_0001', '33-Cría cuervos....txt_0002', '33-Cría cuervos....txt_0004', '33-Cría cuervos....txt_0005'])
#   + Query agregada: 'A pesar del llamado a la guerra, ¿qué dos obstáculos estructurales enf...' (Chunks: ['33-Cría cuervos....txt_0009', '33-Cría cuervos....txt_0012', '33-Cría cuervos....txt_0013'])
#   + Query agregada: 'Una vez muerto Gonzalo Rodríguez Gacha, ¿por qué los líderes de las au...' (Chunks: ['33-Cría cuervos....txt_0015', '33-Cría cuervos....txt_0016'])
#
# --- Procesando Capítulo 34/36: 34-Al filo del caos.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Cuáles fueron las principales justificaciones estratégicas y contextu...' (Chunks: ['34-Al filo del caos.txt_0003', '34-Al filo del caos.txt_0004'])
#   + Query agregada: '¿Cómo el sabotaje político a la propuesta de reforma constitucional de...' (Chunks: ['34-Al filo del caos.txt_0005', '34-Al filo del caos.txt_0006', '34-Al filo del caos.txt_0008', '34-Al filo del caos.txt_0009'])
#   + Query agregada: '¿Qué buscaban añadir los parlamentarios aliados de Pablo Escobar a la ...' (Chunks: ['34-Al filo del caos.txt_0005', '34-Al filo del caos.txt_0006'])
#
# --- Procesando Capítulo 35/36: 35-No es el pasado, es el futuro.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Qué evento clave detuvo el proceso de reformas constitucionales limit...' (Chunks: ['35-No es el pasado, es el futuro.txt_0000', '35-No es el pasado, es el futuro.txt_0001', '35-No es el pasado, es el futuro.txt_0002'])
#   + Query agregada: '¿De qué manera el gobierno de Virgilio Barco utilizó la figura del est...' (Chunks: ['35-No es el pasado, es el futuro.txt_0001', '35-No es el pasado, es el futuro.txt_0002'])
#   + Query agregada: 'Hacia mediados de los años noventa, ¿cuáles fueron las cuatro dimensio...' (Chunks: ['35-No es el pasado, es el futuro.txt_0009', '35-No es el pasado, es el futuro.txt_0010', '35-No es el pasado, es el futuro.txt_0011'])
#
# --- Procesando Capítulo 36/36: 36-La paz.txt ---
# Enviando solicitud a la API de Gemini...
# API respondió con 3 preguntas.
#   + Query agregada: '¿Por qué la paz alcanzada en Colombia, a pesar de sus efectos moderniz...' (Chunks: ['36-La paz.txt_0000'])
#   + Query agregada: '¿Qué caracteriza la naturaleza predominantemente "negativa" de la paz ...' (Chunks: ['36-La paz.txt_0000', '36-La paz.txt_0001', '36-La paz.txt_0002'])
#   + Query agregada: '¿Qué componente de la tríada de paz de Betancur resultó incompleto, y ...' (Chunks: ['36-La paz.txt_0001', '36-La paz.txt_0002'])
#
# Procesamiento completado. Total de 108 preguntas generadas.
# ¡Éxito! 'Gold Standard' guardado en: 'D:\github\plnTallerRAG\data\gold_standard_dataset.json'
